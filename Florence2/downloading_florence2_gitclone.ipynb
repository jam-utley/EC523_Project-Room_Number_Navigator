# %%
# !git lfs install #THIS DID IT I DOWNLOADED THE WEIGHTS MWAAAHHAHAHAHAHAAA
# !git clone https://huggingface.co/microsoft/Florence-2-base
# Out:
# Git LFS initialized.
# Cloning into 'Florence-2-base'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 65 (delta 29), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (65/65), 939.26 KiB | 3.91 MiB/s, done.
# Filtering content: 100% (2/2), 884.67 MiB | 30.11 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

files.download('Florence-2-base.zip')
files.download('cache.zip')

# %%
# !zip -r /content/Florence-2-base.zip /content/Florence-2-base
# Out:
#   adding: content/Florence-2-base/ (stored 0%)
#   adding: content/Florence-2-base/CODE_OF_CONDUCT.md (deflated 61%)
#   adding: content/Florence-2-base/processing_florence2.py (deflated 79%)
#   adding: content/Florence-2-base/README.md (deflated 74%)
#   adding: content/Florence-2-base/.gitattributes (deflated 87%)
#   adding: content/Florence-2-base/LICENSE (deflated 44%)
#   adding: content/Florence-2-base/configuration_florence2.py (deflated 76%)
#   adding: content/Florence-2-base/SUPPORT.md (deflated 45%)
#   adding: content/Florence-2-base/tokenizer_config.json (stored 0%)
#   adding: content/Florence-2-base/model.safetensors (deflated 8%)
#   adding: content/Florence-2-base/pytorch_model.bin (deflated 8%)
#   adding: content/Florence-2-base/vocab.json (deflated 68%)
#   adding: content/Florence-2-base/config.json (deflated 65%)
#   adding: content/Florence-2-base/modeling_florence2.py (deflated 83%)
#   adding: content/Florence-2-base/preprocessor_config.json (deflated 57%)
# ...

# %%
# !zip -r /content/cache.zip /content/cache
# Out:
#   adding: content/cache/ (stored 0%)
#   adding: content/cache/models--microsoft--Florence-2-base/ (stored 0%)
#   adding: content/cache/models--microsoft--Florence-2-base/snapshots/ (stored 0%)
#   adding: content/cache/models--microsoft--Florence-2-base/snapshots/5ca5edf5bd017b9919c05d08aebef5e4c7ac3bac/ (stored 0%)
#   adding: content/cache/models--microsoft--Florence-2-base/snapshots/5ca5edf5bd017b9919c05d08aebef5e4c7ac3bac/configuration_florence2.py (deflated 76%)
#   adding: content/cache/models--microsoft--Florence-2-base/snapshots/5ca5edf5bd017b9919c05d08aebef5e4c7ac3bac/config.json (deflated 65%)
#   adding: content/cache/models--microsoft--Florence-2-base/blobs/ (stored 0%)
#   adding: content/cache/models--microsoft--Florence-2-base/blobs/b8869617ef8dfd0f04d421cf59b83ca662c363ad (deflated 76%)
#   adding: content/cache/models--microsoft--Florence-2-base/blobs/74a4482afd52515c89ae8d7d388a537a16f5d350 (deflated 65%)
# ...
